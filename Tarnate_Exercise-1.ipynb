# %%
ice_cream_rating = 8
sleeping_rating = 10

# %%
first_name = input("First Name")
last_name = input("Last Name")
my_name = first_name + " " + last_name
print (my_name)
# Out:
# First Name Kyla
# Last Name Tarnate
# Kyla Tarnate

# %%
happiness_rating = (ice_cream_rating + sleeping_rating) / 2

# %%
print(type(ice_cream_rating))
print(type(first_name))
print(type(happiness_rating))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %% [markdown]
# Yes, all of the data types made sense to me. None of them were different from what I expected. The variable ice_cream_rating is correctly classified as an integer because it represents a whole number. The variable first_name is a string since it stores text. Lastly, happiness_rating is appropriately identified as a float because it can include decimal values.

# %%
print("My name is ", first_name, "and I give eating ice cream a score of ", ice_cream_rating, "out of 10!")
print("I am ", my_name, "and my sleeping enjoyment rating is ", sleeping_rating, "/ 10!")
print("Based on the factors above, my happiness rating is ", happiness_rating, "out of 10, or ", happiness_rating * 10, "%")
# Out:
# My name is  Kyla and I give eating ice cream a score of  8 out of 10!
# I am  Kyla Tarnate and my sleeping enjoyment rating is  10 / 10!
# Based on the factors above, my happiness rating is  9.0 out of 10, or  90.0 %
